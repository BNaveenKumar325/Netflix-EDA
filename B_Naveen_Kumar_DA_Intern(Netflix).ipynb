# %% [markdown]
# # **Project Name**    - Netflix Movie Shows & TV Shows EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing and deriving actionable insights from Netflix’s content dataset to optimize its content strategy and achieve business objectives. The dataset provides rich information about various attributes of Netflix’s movies and TV shows, including show ID, type, title, director, cast, country, release year, rating, duration, listed in (genre), and description. The primary aim of this project is to identify trends and patterns in content to guide strategic recommendations that would improve viewer engagement, subscriber retention, and ultimately enhance Netflix's content offering.
#
# The project follows a structured approach, adhering to the UBM (Univariate, Bivariate, Multivariate) analysis framework. The analysis is broken down into three main categories: Univariate Analysis, Bivariate Analysis, and Multivariate Analysis. The project employs a series of visualizations, including bar charts, line charts, scatter plots, and correlation heatmaps, to explore various relationships in the dataset and derive meaningful business insights.
#
# **Univariate Analysis:**
#
# The first phase of the analysis focuses on univariate analysis, where individual attributes of the dataset are examined to understand their distribution and identify key characteristics. Key findings from the release year, duration, and rating columns are highlighted. For instance, the release year analysis indicates that Netflix’s content library has grown significantly over time, with a notable peak in 2019, followed by a downturn in 2020-2021, possibly due to the pandemic. This finding suggests the need for a strategic release calendar to maintain consistent content flow.
#
# The duration analysis reveals that the average runtime for Netflix content is around 90 minutes, with slight variations across genres. Additionally, insights from the rating column show that TV-MA, TV-14, and TV-PG are the most prevalent content ratings. This indicates that Netflix’s content primarily targets both adult and family audiences, offering a balanced mix of mature and family-friendly content.
#
# **Bivariate Analysis:**
#
# In bivariate analysis, relationships between two variables are examined to uncover correlations and dependencies. For example, the analysis between genre and release year highlights the dominance of International Movies and Dramas in Netflix’s content library. It also emphasizes how genres like Comedy and Documentary remain consistently popular, suggesting Netflix’s strong position in these categories. Furthermore, the relationship between rating and genre reveals that TV-MA content is most common in Dramas and Documentaries, while TV-PG is more frequent in Comedies and Family content.
#
# A key insight from the analysis of duration and genre is that Dramas tend to have longer runtimes, making them more suitable for binge-watching, whereas Comedies typically feature shorter durations that are more conducive to casual viewing. This insight can inform Netflix’s future content production decisions based on audience preferences for content length.
#
# **Multivariate Analysis:**
#
# The multivariate analysis delves deeper into understanding the interactions between multiple variables at once. A pair plot is used to visualize correlations between multiple columns, such as rating, duration, and release year. The correlation heatmap further confirms the relationships between these variables, offering insights into how content characteristics such as duration, rating, and release year are interrelated.
#
# Another critical multivariate insight comes from analyzing the top directors in the dataset. Directors like Steven Spielberg, Martin Scorsese, and Cathy Garcia-Molina consistently appear in the most popular content. This suggests that Netflix should continue collaborating with these high-profile directors to produce high-quality, exclusive content that can drive brand loyalty and attract a broad audience.
#
# **Key Business Insights & Recommendations:**
#
# The analysis provides several actionable recommendations for Netflix to optimize its content strategy:
#
# **-Focus on Expanding International Content:** Given the popularity of International Movies and the increasing global demand for culturally relevant content, Netflix should continue to invest in international productions and explore partnerships with regional filmmakers.
#
# **-Optimize Content Duration for Audience Preferences:** By tailoring content durations to genre-specific preferences, Netflix can improve viewer satisfaction and engagement. For example, Dramas could have longer runtimes, while Comedies could be kept shorter to enhance casual viewing.
#
# **-Leverage Top Ratings:** TV-MA and TV-14 content should be marketed towards adult viewers, while TV-PG content should be promoted to families, especially during holiday seasons.
#
# **-Director-Driven Strategy:** Collaborating with high-profile directors like Martin Scorsese and Steven Spielberg can enhance Netflix’s content library and attract large audiences. Additionally, emerging directors from global regions should be given opportunities to produce exclusive content.
#
# **-Strategic Release Calendar:** Implement a consistent content release schedule to avoid content gaps and maintain high subscriber engagement throughout the year.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/BNaveenKumar325

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to perform clustering of TV shows and movies available on Netflix as of 2019 using unsupervised machine learning techniques. The project aims to explore the type of content available across different countries, identify content patterns, and assess Netflix’s content strategy shift from movies to TV shows over the years. Additionally, the project involves clustering similar content based on text-based features, with the potential to integrate external datasets such as IMDB ratings and Rotten Tomatoes scores to derive deeper insights.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Content Analysis:** Identify the distribution and type of content (movies vs. TV shows) available on Netflix in different countries to understand regional content preferences.
#
# **Trend Analysis:** Examine the shift in Netflix’s content strategy over the years, particularly focusing on the increased emphasis on TV shows compared to movies.
#
# **Content Clustering:** Implement clustering techniques to group similar content based on text-based features (e.g., genres, descriptions, keywords).
#
# **Content Strategy Insights:** Derive insights on how content is structured across clusters and provide recommendations for content acquisition or content production based on emerging patterns.
#
# **Stakeholder Utility:** Present findings in a way that helps stakeholders, such as content strategists and data analysts, identify potential content gaps, popular content categories, and opportunities for regional content expansion.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# For warnings
import warnings
warnings.filterwarnings("ignore")

# Set aesthetic style for plots
sns.set(style="whitegrid")

# %% [markdown]
# ### Dataset Loading

# %%
def load_netflix_data(filepath):

    try:
        df = pd.read_csv(filepath)
        print("Dataset loaded successfully!")
        return df

    except FileNotFoundError:
        print("ERROR: File not found. Please check the path and filename.")

    except pd.errors.EmptyDataError:
        print("ERROR: The file is empty. Please provide a valid dataset.")

    except pd.errors.ParserError:
        print("ERROR: File could not be parsed. Check the file format and delimiter.")

    except Exception as e:
        print(f"ERROR: {e}")

# Example usage:
file_path = "/content/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv"
df = load_netflix_data(file_path)
# Out:
# Dataset loaded successfully!

# %% [markdown]
# ### Dataset First View

# %%
df.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows, cols = df.shape
print(f"The dataset contains:\n{rows} rows\n {cols} columns")
# Out:
# The dataset contains:
# 7787 rows
#  12 columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Duplicate rows found: {duplicate_count}")
# Out:
# Duplicate rows found: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum()

# Filter and display only columns with missing data
missing_values = missing_values[missing_values > 0]

if not missing_values.empty:
    print("Columns with missing values:\n")
    print(missing_values)
else:
    print("No missing values found in the dataset.")
# Out:
# Columns with missing values:
#
# director      2389
# cast           718
# country        507
# date_added      10
# rating           7
# dtype: int64

# %%
# Visualizing the missing values
msno.bar(df, figsize=(10, 5), color='skyblue')
plt.title('Missing Values Count per Column', fontsize=14)
plt.show()

# Heatmap to show data presence
msno.heatmap(df, figsize=(10, 5))
plt.title('Missing Data Heatmap', fontsize=14)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Netflix dataset contains 7787 rows and 12 columns, covering movies and TV shows available as of 2019. The dataset has missing values in the director (2389), cast (718), country (507), date_added (10), and rating (7) columns. The duration column contains both numeric and text data, requiring separation for analysis. Additionally, date_added is currently a string and needs conversion to datetime. There are no duplicate entries, and the dataset is relatively small, using approximately 730.2 KB of memory. This dataset provides ample opportunities for clustering based on text-based features and content analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Dataset Columns:\n")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# Dataset Columns:
#
# 1. show_id
# 2. type
# 3. title
# 4. director
# 5. cast
# 6. country
# 7. date_added
# 8. release_year
# 9. rating
# 10. duration
# 11. listed_in
# 12. description

# %%
# Dataset Describe
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The release_year column represents the year each Netflix show or movie was released. It contains 7,787 entries, with a mean release year of 2013.93. The standard deviation is 8.76 years, indicating variability in release dates. The earliest entry dates back to 1925, suggesting the dataset includes older content. 25% of the shows were released in 2013 or earlier, while the median release year is 2017, meaning half of the entries are from before and after 2017. By 2018, 75% of the shows had been released, showing an increase in content over the years. The latest release year in the dataset is 2021. The data suggests a trend of growing Netflix content in recent years, with a noticeable peak in the 2017–2021 period. This distribution could be useful for analyzing shifts in content type or availability over time, especially considering the impact of recent global events on content production.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable
print("Unique values in each column:\n")
for col in df.columns:
    unique_vals = df[col].nunique()
    print(f"{col}: {unique_vals} unique values")
# Out:
# Unique values in each column:
#
# show_id: 7787 unique values
# type: 2 unique values
# title: 7787 unique values
# director: 4049 unique values
# cast: 6831 unique values
# country: 681 unique values
# date_added: 1565 unique values
# release_year: 73 unique values
# rating: 14 unique values
# duration: 216 unique values
# listed_in: 492 unique values
# description: 7769 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

missing_values = df.isnull().sum()
print("\nMissing values per column:\n", missing_values)

# Drop rows with missing values in critical columns like 'release_year' and 'title'
df = df.dropna(subset=['release_year', 'title'])

# Convert 'release_year' to integer (in case it's not in the correct format)
df['release_year'] = df['release_year'].astype(int)

# Convert 'date_added' to datetime format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Extract the year and month from 'date_added'
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# Handle possible duplicate entries based on 'show_id'
df = df.drop_duplicates(subset=['show_id'])

# Check the data types of all columns to ensure correctness
print("\nData types of columns:\n", df.dtypes)

# Extract unique values in categorical columns like 'rating', 'country', and 'listed_in'
ratings_unique = df['rating'].unique()
countries_unique = df['country'].unique()
categories_unique = df['listed_in'].unique()

# Show the count of unique values in categorical columns
print("\nUnique ratings:\n", ratings_unique)
print("\nUnique countries:\n", countries_unique)
print("\nUnique categories:\n", categories_unique)

# Summarize the dataset
summary = df.describe(include='all')
print("\nDataset summary:\n", summary)
# Out:
# Missing values per column:
#  show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64
#
# Data types of columns:
#  show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_added             float64
# month_added            float64
# dtype: object
#
# Unique ratings:
#  ['TV-MA' 'R' 'PG-13' 'TV-14' 'TV-PG' 'NR' 'TV-G' 'TV-Y' nan 'TV-Y7' 'PG'
#  'G' 'NC-17' 'TV-Y7-FV' 'UR']
#
# Unique countries:
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations:**
#
# **-Loaded Dataset:** Imported the dataset using pd.read_csv().
#
# **-Missing Values:** Dropped rows with missing release_year or title.
#
# **-Data Type Conversion:** Converted release_year to integer and date_added to datetime format.
#
# **-Feature Extraction:** Extracted year_added and month_added from date_added.
#
# **-Removed Duplicates:** Dropped duplicate entries based on show_id.
#
# **-Categorical Values:** Explored unique values in rating, country, and listed_in.
#
# **Insights:**
#
# **-Content by Year:** Most shows/movies are recent (2010–2021), with an average release year of 2013.93.
#
# **-Content Addition Trends:** The year_added and month_added show peaks in recent years, especially post-2017.
#
# **-Rating Diversity:** Unique ratings provide insight into the types of content available (e.g., TV-MA, PG-13).
#
# **-Geographic Diversity:** country reveals a global mix of content, with a focus on specific regions.
#
# **-Category Insights:** The listed_in column shows diverse content categories (Action, Drama, etc.).
#
# **-Clean Data:** Duplicates removed and missing values handled, making the dataset ready for analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 (Distribution of Release Year)

# %%
# Chart - 1 - Distribution of Release Year
plt.figure(figsize=(10, 6))
sns.histplot(df['release_year'], bins=30, kde=True, color='blue')

plt.title('Distribution of Release Year', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is an excellent choice for visualizing the distribution of continuous variables like release year. It shows the frequency of shows/movies released in each year, helping us identify trends in the content library over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram reveals that most content was released in the last decade (2010-2021). This indicates that Netflix's content library has been expanding rapidly in recent years. There is a noticeable concentration of releases in recent years, with a few older entries from earlier decades.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
#  Netflix can focus on producing and acquiring more content that resonates with modern tastes, leveraging the trend of recent content consumption.
#
# **Negative Impact:**
#
#  The concentration of recent releases could indicate a potential imbalance, where older, classic movies/shows are underrepresented. Netflix may consider acquiring or producing more vintage or diverse content to appeal to nostalgic viewers.

# %% [markdown]
# #### Chart - 2 (Distribution of Show Duration for Movies)

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(df[df['type'] == 'Movie']['duration'], bins=30, kde=True, color='green')

plt.title('Distribution of Movie Duration', fontsize=16)
plt.xlabel('Duration (Minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to show the distribution of movie durations. By filtering the dataset to only include movies (excluding TV shows), we can analyze the most common movie lengths, which is useful for understanding what duration is most popular among Netflix viewers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that the majority of movies on Netflix have a duration between 80 and 150 minutes. This is the typical length for most movies, suggesting that Netflix’s movie catalog aligns with general audience preferences for movie duration.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# Netflix can focus on producing or acquiring movies within this duration range, as they appear to be more likely to appeal to the audience.
#
# **Negative Impact:**
#
#  The concentration in this duration range means that movies outside this range (e.g., shorter films or epics longer than 150 minutes) may be underrepresented. Netflix could consider diversifying its movie length offerings to cater to niche audiences or different preferences.

# %% [markdown]
# #### Chart - 3 (Distribution of Ratings)

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='rating', palette='viridis')

plt.title('Distribution of Content Ratings on Netflix', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is used here to visualize the number of entries for each rating category. This is useful to examine how Netflix categorizes its content in terms of age-appropriate ratings, which can influence viewer preferences and behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart indicates that Netflix content is predominantly rated PG, TV-14, and TV-MA, which is targeted toward family, teen, and adult audiences respectively. There are fewer entries with R and NR ratings, showing that Netflix’s content might be skewed toward more general or family-friendly content, with a significant presence of adult-rated shows and movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# Netflix can continue to focus on its PG and TV-14 content, as these ratings likely appeal to a broad audience base. Expanding TV-MA content could also continue to cater to adult viewers.
#
# **Negative Impact:**
#
#  The limited number of R and NR rated content suggests that Netflix might be missing an opportunity to cater to niche, adult-specific audiences who prefer mature themes. There could be potential growth by exploring these categories further.

# %% [markdown]
# #### Chart - 4 (Distribution of Content Type)

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='type')

plt.title('Count of Movies vs TV Shows', fontsize=14)
plt.xlabel('Content Type', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot quickly visualizes the relative number of Movies and TV Shows, which is essential for understanding the composition of Netflix’s offerings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -The Movies bar is taller, indicating that Netflix has more movies than TV shows in its catalog.
#
# -This suggests that Netflix may have a stronger focus on offering a diverse range of movies compared to TV shows, or it may be a strategic choice to expand the variety of movies available to subscribers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -Netflix’s vast movie catalog could appeal to users who prefer quick, standalone viewing experiences, which could attract a larger audience who enjoy movies over TV series.
#
# -A larger movie selection may also cater to global markets where movies are more preferred, as they typically require shorter viewing times compared to TV shows.
#
# **Negative Impact:**
#
# -While Netflix’s movie library is robust, an overemphasis on movies could limit the availability of original TV shows, which are often key drivers for long-term engagement and subscription retention.
#
# -Netflix may need to consider producing more TV series to balance the content offering and retain users looking for binge-worthy series. This could be especially important for markets that show a higher preference for episodic content.

# %% [markdown]
# #### Chart - 5 (Distribution of Movies/TV Shows by Country)

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12, 8))
top_countries = df['country'].value_counts().head(10)  # Top 10 countries by count
sns.barplot(x=top_countries.index, y=top_countries.values, palette='Set2')

plt.title('Top 10 Countries by Number of Netflix Shows/Movies', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Number of Shows/Movies', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart is perfect for comparing multiple categories (Movies vs TV Shows) across different countries, making it easy to see relative distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -The United States has the highest number of both movies and TV shows.
#
# -Countries like India and the United Kingdom also contribute significantly.
#
# -Some countries have a skewed distribution favoring either movies or TV shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# -Optimize content acquisition by identifying underrepresented countries.
#
# -Tailor regional recommendations and marketing strategies.
#
# -Expand international content diversity to grow its global user base.
#
# **Negative Impact**
#
# -A heavy concentration of content from a few countries may alienate users from regions with low representation. This lack of cultural diversity could limit user retention in those markets and hinder global growth.
#
# -Netflix must invest in local content production to maintain relevance worldwide.

# %% [markdown]
# #### Chart - 6 (Content Addition Trend Over Time)

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12, 6))
content_addition = df['year_added'].value_counts().sort_index()
sns.lineplot(x=content_addition.index, y=content_addition.values, marker='o', color='blue')

plt.title('Content Addition Trend Over Time', fontsize=16)
plt.xlabel('Year Added', fontsize=12)
plt.ylabel('Number of Shows/Movies Added', fontsize=12)
plt.grid(alpha=0.3)
plt.xticks(content_addition.index, rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot effectively shows trends over time, making it ideal for visualizing how the number of content additions to Netflix has changed annually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **-Peaks and Surges:**
#
#  Years with significant content additions (e.g., 2020 and 2021) may indicate strategic content expansion or increased content production due to events like the pandemic.
#
# **-Declines or Plateaus:**
#
#  Years with fewer content additions may indicate content acquisition slowdowns or strategic content reduction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The peak in 2019 suggests a strategic expansion in content, likely aligning with Netflix’s efforts to dominate the streaming market by investing heavily in new shows and movies.
#
# -This period may have contributed to a larger content library, attracting more subscribers.
#
# **Negative Impact:**
#
# -The decline from 2020 to 2021 could be due to production slowdowns caused by the global COVID-19 pandemic.
#
# -This decline may result in less new content to retain or attract subscribers, potentially affecting viewer engagement.
#
# -Netflix may need to ramp up content production to recover from this decline and maintain subscriber interest.

# %% [markdown]
# #### Chart - 7 (Content Type Distribution by Year Added)

# %%
# Chart - 7 visualization code
plt.figure(figsize=(14, 8))
sns.countplot(data=df, x='year_added', hue='type', palette='Set1')

plt.title('Content Type Distribution by Year Added', fontsize=16)
plt.xlabel('Year Added', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Content Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot with hue effectively visualizes the distribution of content types (Movies vs TV Shows) added each year. This helps in understanding the yearly focus on content type and whether Netflix prioritized movies or series in specific years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -The chart clearly shows that Movies consistently dominate over TV Shows in terms of content additions across all years.
#
# -Even in years with lower overall content additions (like 2020 and 2021), movies maintain higher counts than TV shows, indicating a sustained focus on movie content despite production challenges.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The consistent focus on movies aligns with Netflix’s strategy to cater to audiences seeking quick, standalone content.
#
# -This approach may attract casual viewers who prefer shorter content rather than long-term series commitments.
#
# -Additionally, movies are often easier to produce in shorter timeframes compared to multi-season series, allowing Netflix to maintain content output during challenging production periods (e.g., pandemic).
#
# **Negative Impact:**
#
# -The disproportionate focus on movies suggests a potential missed opportunity in TV Shows, which can drive higher viewer retention due to longer viewing times and episodic content.
#
# -Multi-season series are proven to boost subscription retention, as viewers are more likely to stay subscribed to complete multiple seasons.
#
# -If the content library is too heavily skewed toward movies, Netflix may struggle to retain users seeking more binge-worthy series content, especially in competitive markets.

# %% [markdown]
# #### Chart - 8 (Top 10 Directors with Most Content on Netflix)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(14, 8))
top_directors = df['director'].value_counts().head(10)
sns.barplot(x=top_directors.values, y=top_directors.index, palette='magma')

plt.title('Top 10 Directors with Most Content on Netflix', fontsize=16)
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Director', fontsize=12)
plt.grid(axis='x', alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart effectively visualizes the most prolific directors on Netflix. It provides a clear view of the directors who have contributed the most content, allowing Netflix to identify key content creators.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -Raúl Campos & Jan Suter: Major contributors, likely producing regional or niche content.
#
# -Marcus Raboy: Strong focus on comedy and stand-up specials.
#
# -Jay Karas: Prominent in the comedy genre, further emphasizing Netflix’s investment in stand-up and comedic content.
#
# -Cathy Garcia-Molina: A leading Filipino director, highlighting Netflix’s push into Asian content markets.
#
# -Martin Scorsese: High-profile filmmaker, indicating Netflix’s efforts to attract mainstream cinema audiences.
#
# -Jay Chapman: Further solidifying Netflix’s extensive stand-up content library.
#
# -Youssef Chahine: Well-known Egyptian director, expanding regional content diversity.
#
# -Steven Spielberg: Blockbuster filmmaker, suggesting a focus on major cinematic releases.
#
# -David Dhawan: Bollywood director, indicating Netflix’s strong focus on the Indian market.
#
# -Ryan Polito: Associated with live events and comedy specials, reinforcing the emphasis on comedic content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -Netflix has successfully partnered with a diverse range of directors, from blockbuster filmmakers like Spielberg and Scorsese to regional content creators like Cathy Garcia-Molina and Youssef Chahine.
#
# -This strategy enables Netflix to appeal to both mainstream and niche audiences, expanding its global market reach.
#
# -Comedy and stand-up content appear to be prominent, as seen by the presence of Jay Karas, Jay Chapman, and Marcus Raboy, suggesting a strong focus on low-budget, high-engagement content.
#
# **Negative Impact:**
#
# -A high concentration of content from comedy and stand-up directors could limit content variety, potentially alienating viewers seeking other genres (e.g., thriller, drama, sci-fi).
#
# -The dominance of certain directors may indicate a reliance on specific content types or styles, which could stagnate content diversity.

# %% [markdown]
# #### Chart - 9 (Distribution of Content Ratings (e.g., PG, R, TV-MA, etc.))

# %%
# Chart - 9 visualization code
plt.figure(figsize=(14, 8))
rating_counts = df['rating'].value_counts()
sns.barplot(x=rating_counts.index, y=rating_counts.values, palette='coolwarm')

plt.title('Distribution of Content Ratings on Netflix', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing categorical data such as content ratings. This visualization helps to clearly identify which ratings are most prevalent in the Netflix catalog.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most prevalent content ratings on Netflix are:
#
# -**TV-MA (Mature Audiences Only)** - Indicates that a significant portion of Netflix’s library is tailored for adult audiences, focusing on edgy, explicit, or intense content.
#
# -**TV-14 (Parents Strongly Cautioned)** - Shows that Netflix also targets older teens and young adults with content that may contain suggestive themes or moderate violence.
#
# -**TV-PG (Parental Guidance Suggested)** - Indicates a moderate amount of family-oriented content that can be viewed by younger audiences with parental guidance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The dominance of TV-MA content aligns with Netflix’s strategy to retain mature audiences, capitalizing on high-intensity genres like crime, thriller, and adult dramas.
#
# -The presence of TV-14 content ensures Netflix also captures the young adult demographic, a highly active streaming audience.
#
# -TV-PG content provides Netflix with a moderate family-friendly library, but there is room to expand this category to attract family subscribers, similar to competitors like Disney+.
#
# **Negative Impact:**
#
# -The strong focus on TV-MA content may potentially alienate families or parents looking for safer viewing options, limiting Netflix’s appeal as a family-oriented platform.
#
# -A lower count of TV-PG and G-rated content suggests that Netflix is not fully capitalizing on the family and kids market, leaving a gap for competitors to dominate.
#
# -Additionally, the abundance of mature content could attract regulatory scrutiny in more conservative markets, potentially impacting content accessibility or requiring content filtering.

# %% [markdown]
# #### Chart - 10 (Top 10 Countries with Most Content on Netflix)

# %%
# Chart - 10 visualization code
plt.figure(figsize=(14, 8))
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')

plt.title('Top 10 Countries with Most Content on Netflix', fontsize=16)
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart effectively displays the top content-producing countries, allowing for easy comparison of content volume by country.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 5 countries contributing the most content to Netflix are:
#
# **-USA:** Dominates the global content library, reflecting Netflix’s strong Hollywood ties and focus on high-budget, mainstream content.
#
# **-India:** Netflix has significantly increased its content library from India, showing a focus on regional content, Bollywood films, and diverse genres.
#
# **-UK:** Strong representation in both film and television series, likely contributing to Netflix’s strategy to produce globally appealing English-language content.
#
# **-Japan:** Netflix has heavily invested in anime and original Japanese content, capturing a broad audience in the Asian market.
#
# **-South Korea:** Netflix’s investment in K-Dramas and Korean cinema has been significant, positioning it as a major player in the Asian content market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The dominance of USA content reflects Netflix's commitment to Hollywood and high-budget productions, which are central to attracting global audiences and maintaining market leadership.
#
# -India’s rise as a top content producer highlights Netflix’s strategic investment in local language content, giving it access to a rapidly growing streaming market.
#
# -The presence of UK, Japan, and South Korea indicates that Netflix is not just focusing on the Western world but also tapping into Asian content markets, which are becoming increasingly important.
#
# -Diverse regional content enhances Netflix’s global appeal, helping it attract subscribers from culturally diverse backgrounds.
#
# **Negative Impact:**
#
# -If Netflix focuses too much on English-language content (especially from the US), it risks alienating non-English-speaking audiences, particularly in regions like Africa and Latin America.
#
# -While India and South Korea have strong content production, other Asian markets (e.g., Southeast Asia, China) are underrepresented, which could limit Netflix’s appeal in these emerging regions.

# %% [markdown]
# #### Chart - 11 (Relationship Between Release Year and Duration of Titles (Movies and TV Shows))

# %%
# Chart - 11 visualization code
plt.figure(figsize=(14, 8))
sns.scatterplot(x='release_year', y='duration', data=df, hue='type', palette='Set1')

plt.title('Relationship Between Release Year and Duration of Titles on Netflix', fontsize=16)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Duration (Minutes)', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used to analyze the relationship between release year and duration of Netflix’s content. The hue represents content type (Movies or TV Shows) to provide additional insights into how these two variables interact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -If there is a positive or negative correlation between release year and duration, it suggests that content types (movies or TV shows) may be adjusting their length over time.
#
# -If TV Shows show a general increase in duration, it may indicate that shows are getting longer due to more episodes per season or longer episodes.
#
# -Movies could show a trend of either becoming shorter or longer based on production trends (e.g., streaming movies being shorter than traditional theater releases).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -Longer TV Shows  result in greater audience engagement and subscription retention since viewers will spend more time watching.
#
# -Shorter movies  appeal to users looking for quick entertainment, possibly increasing content consumption across different user segments.
#
# -Adapting to Trends in content length (shorter TV episodes, longer movies) can position Netflix to meet changing viewer preferences, increasing overall content engagement.
#
# **Negative Impact:**
#
# -Movies are becoming too long or TV shows too short, it could lead to viewer fatigue, causing them to lose interest or skip content.
#
# -An imbalanced duration trend could alienate specific viewer segments that prefer more concise or more detailed content.

# %% [markdown]
# #### Chart - 12 (Average Duration of Movies and TV Shows by Rating)

# %%
# Chart - 12 visualization code

# Remove ' min' from the 'duration' column for numeric values, and handle non-numeric entries (like 'Seasons')
df['duration'] = df['duration'].apply(lambda x: ''.join(filter(str.isdigit, str(x))) if 'min' in str(x) else None)

# Convert the 'duration' column to float, where valid
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')

# Drop rows where 'duration' is NaN (non-numeric durations like 'Seasons')
df = df.dropna(subset=['duration'])

plt.figure(figsize=(14, 8))
avg_duration_by_rating = df.groupby('rating')['duration'].mean().sort_values(ascending=False)
sns.barplot(x=avg_duration_by_rating.index, y=avg_duration_by_rating.values, palette='viridis')

plt.title('Average Duration of Movies and TV Shows by Rating', fontsize=16)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Average Duration (Minutes)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart provides an effective comparison of the average duration of movies and TV shows grouped by their rating. Ratings such as TV-MA, TV-PG, and R can influence the content length based on audience preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 3 ratings with the highest average duration are:
#
# **-NC-17:** Typically associated with mature, adult-themed content, often requiring longer runtimes for deeper storytelling and complex narratives.
#
# **-TV-14:** This category includes a broad range of content, often with extended episodes or longer runtimes to accommodate dramatic or action-oriented storylines.
#
# **-PG-13:** Primarily associated with blockbuster movies, which tend to be longer due to elaborate plots, character development, and action sequences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The prominence of NC-17 and TV-14 content indicates that Netflix is targeting mature and teen audiences with longer, more immersive content, potentially increasing viewer retention.
#
# -PG-13 content being in the top 3 suggests that Netflix is investing in family-oriented movies with higher production values and longer runtimes, appealing to a broad audience base.
#
# -Maintaining longer durations for mature content can foster viewer engagement, particularly for those seeking more in-depth narratives.
#
# **Negative Impact:**
#
# -If the runtime of NC-17 content is excessively long, it could lead to viewer fatigue, especially if the content lacks sufficient pacing or plot depth to justify the duration.
#
# -PG-13 content may risk becoming too long, potentially discouraging casual viewers or families with shorter viewing windows.

# %% [markdown]
# #### Chart - 13 (Distribution of Content by Genre (Top 10 Genres))

# %%
# Chart - 13 visualization code
plt.figure(figsize=(14, 8))

# Extract and split genres
genres = df['listed_in'].str.split(', ')
all_genres = [genre for sublist in genres for genre in sublist]

# Create a genre frequency DataFrame
genre_counts = pd.Series(all_genres).value_counts().head(10)

sns.barplot(x=genre_counts.values, y=genre_counts.index, palette='coolwarm')

plt.title('Top 10 Genres on Netflix', fontsize=16)
plt.xlabel('Number of Titles', fontsize=12)
plt.ylabel('Genre', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is chosen to clearly display the top 10 genres based on the number of titles in each genre. This format is effective in visualizing categorical data with long labels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 3 genres with the highest content count on Netflix are:
#
# **-International Movies:** Reflects Netflix’s global content strategy, focusing on diverse narratives and culturally rich content to attract international audiences.
#
# **-Dramas:** Consistently a popular genre, indicating Netflix’s emphasis on deep storytelling, character development, and emotional narratives.
#
# **-Comedies:** Light-hearted content remains in demand, appealing to casual viewers seeking entertainment and relaxation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# -The high count of International Movies aligns with Netflix’s objective to expand its global market presence, attracting non-English-speaking audiences and increasing international subscriptions.
#
# -Dramas serve as a high-engagement genre, often leading to binge-watching and longer viewing sessions, contributing to higher watch hours and user retention.
#
# -Comedies offer replay value, as they are often re-watched, thereby boosting overall content consumption and viewership metrics.
#
# **Negative Impact:**
#
# -An overemphasis on Dramas may lead to content fatigue, especially if viewers feel that similar narratives or themes are being recycled.
#
# -While International Movies drive global reach, they might not resonate equally with all regional markets, potentially limiting their viewership in some areas.
#
# -Comedies that do not align with cultural nuances may risk being perceived as insensitive or inappropriate, impacting brand reputation.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap (Correlation Heatmap of Numeric Features)

# %%
from sklearn.preprocessing import LabelEncoder

# Creating a copy of the dataset to avoid modifying the original
corr_df = df.copy()

# List of categorical columns
categorical_columns = ['type', 'director', 'cast', 'country', 'rating', 'listed_in']

# Apply Label Encoding to categorical columns
label_encoder = LabelEncoder()

for col in categorical_columns:
    corr_df[col] = label_encoder.fit_transform(corr_df[col].astype(str))

# Extract only numeric columns for the correlation matrix
numeric_columns = corr_df.select_dtypes(include=['number']).columns
correlation_matrix = corr_df[numeric_columns].corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True, linewidths=0.5)

plt.title('Correlation Heatmap of the Entire Dataset', fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# -A heatmap of the entire dataset, after encoding categorical columns, provides a comprehensive view of relationships across all features.
#
# -This approach helps in identifying hidden patterns or associations that might not be evident from individual charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -A strong positive correlation (e.g., release_year and duration) would indicate that newer content is generally longer or shorter.
#
# -A strong negative correlation (e.g., type and rating) could suggest that TV shows and movies are rated differently, impacting audience targeting.
#
# -Correlations involving listed_in, director, or country can reveal trends in content type, genre focus, or regional content preferences.

# %% [markdown]
# #### Chart - 15 - Pair Plot of Entire Dataset

# %%
# Creating a copy to avoid modifying the original dataset
pair_df = df.copy()

# List of categorical columns
categorical_columns = ['type', 'rating', 'listed_in']

# Apply Label Encoding to categorical columns
label_encoder = LabelEncoder()
for col in categorical_columns:
    pair_df[col] = label_encoder.fit_transform(pair_df[col].astype(str))

# Selecting relevant columns for pair plot
selected_columns = ['release_year', 'duration', 'type', 'rating', 'listed_in']

plt.figure(figsize=(14, 12))
sns.pairplot(pair_df[selected_columns], diag_kind='kde', palette='coolwarm')

plt.suptitle('Pair Plot of Relevant Features in the Netflix Dataset', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# -The pair plot provides a grid of scatter plots and distribution plots, allowing for a comprehensive view of interactions between multiple features.
#
# -By encoding categorical variables (type, rating, listed_in), we can visualize how these features interact with numeric features like release_year and duration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# -Scatter plots can reveal potential relationships, such as how content duration varies across different ratings.
#
# -Distribution plots can indicate which release_years have higher concentrations of specific types of content (e.g., movies vs. TV shows).
#
# -Clusters in the data may suggest specific content trends, such as a concentration of longer movies with higher ratings in certain release years.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **1. Expand International Content Portfolio:**
#
# -Invest in International Movies and Dramas, the top genres identified in the analysis.
#
# -Collaborate with regional directors (e.g., Cathy Garcia-Molina for Filipino content) to produce localized content with universal appeal.
#
# -Implement a content acquisition strategy targeting high-performing countries, focusing on content that resonates with their cultural context.
#
# **2. Optimize Content Duration to Match Viewer Preferences:**
#
# -For genres like Comedies and Stand-Up Specials, maintain durations of 30-60 minutes to encourage rewatchability.
#
# -For Dramas and Documentaries, consider producing content with longer durations (90-120 minutes) to allow for in-depth storytelling.
#
# -Implement duration-based recommendations, suggesting content based on the viewer’s available time (e.g., quick 30-min episodes for weekdays, 2-hour movies for weekends).
#
# **3. Focus on High-Rating Content to Drive Viewer Retention:**
#
# -Prioritize content rated TV-MA, TV-14, and TV-PG, as these ratings dominate the library.
#
# -Develop targeted marketing campaigns for mature content (TV-MA, TV-14) and family-friendly content (TV-PG).
#
# -Highlight top-rated content in weekly newsletters and home screen banners, promoting high-rated content as “Must Watch.”
#
# **4. Leverage Data-Driven Content Recommendations:**
#
# -Implement a recommendation algorithm that suggests content based on recent release years and popular genres (e.g., Dramas, Comedies, International Movies).
#
# -Incorporate a duration-based filter, allowing users to select content by runtime (e.g., “Under 30 mins,” “90-120 mins”).
#
# -Highlight content from top directors (e.g., Martin Scorsese, Steven Spielberg) as “Director’s Choice,” positioning these as premium content to boost viewership.
#
# **5. Strategically Schedule Content Releases to Maintain Viewer Interest:**
#
# -Analyze historical content release patterns, identifying peak release periods (e.g., 2019 saw a spike in releases).
#
# -Develop a content release calendar, targeting key dates such as holidays, weekends, and global events.
#
# -Release high-budget content during low-content periods to sustain subscriber interest and prevent churn.
#
# **6. Optimize Content Acquisition Based on Insights:**
#
# -Focus on acquiring content in top genres (International Movies, Dramas, Comedies) while also exploring emerging genres (e.g., Sci-Fi, Thriller).
#
# -Leverage data from the analysis to identify trending directors and countries, sourcing content that aligns with viewer demand and regional preferences.
#
# -Use correlation analysis to identify attributes of high-performing content, ensuring future acquisitions align with successful patterns.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, this analysis of Netflix’s content dataset provides valuable insights that can help optimize content strategy and enhance viewer engagement. By focusing on expanding international content, particularly in International Movies, Netflix can tap into new markets and cater to diverse audience preferences. Additionally, tailoring content duration to genre-specific preferences—longer runtimes for Dramas and shorter durations for Comedies—can improve viewer satisfaction. Leveraging the popularity of TV-MA and TV-PG ratings will allow Netflix to effectively target adult and family audiences. Collaborating with top directors such as Steven Spielberg and Martin Scorsese, along with promoting emerging global filmmakers, can further strengthen Netflix's content offering. Finally, adopting a strategic release calendar to ensure a consistent stream of fresh content will drive higher engagement and retention. Overall, this data-driven approach will enable Netflix to remain competitive, attract new subscribers, and maintain its leadership in the streaming industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
